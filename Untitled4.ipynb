# %% [markdown]
# <a href="https://colab.research.google.com/github/risnariha/RNNs/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
df = pd.read_csv("temp_data.csv" , delimiter="\t", header=None, names=["Date", "Temp"])

# %%
df
# Out:
#                  Date  Temp
# 0         Date,"Temp"   NaN
# 1     1981-01-01,20.7   NaN
# 2     1981-01-02,17.9   NaN
# 3     1981-01-03,18.8   NaN
# 4     1981-01-04,14.6   NaN
# ...               ...   ...
# 3646  1990-12-27,14.0   NaN
# 3647  1990-12-28,13.6   NaN
# 3648  1990-12-29,13.5   NaN
# 3649  1990-12-30,15.7   NaN
# 3650  1990-12-31,13.0   NaN
#
# [3651 rows x 2 columns]

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(df["Date"])
